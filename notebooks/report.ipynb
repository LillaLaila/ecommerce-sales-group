# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
import pandas as pd
from src.ecommerce import EcommerceAnalyzer



# df = io_utils.load_data()

check = EcommerceAnalyzer()

df = check.load_data()

check.top_3(df)
# check.barKategori(df)
# check.barStader(df)
check.mean(df)
check.intaktStad(df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import os, sys
#       2 sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "src")))
# ----> 3 from src.ecommerce import EcommerceAnalyzer
#       5 check = EcommerceAnalyzer()
#       7 df = check.load_data()
#
# ModuleNotFoundError: No module named 'src'
