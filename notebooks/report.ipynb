# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
import pandas as pd
from src.ecommerce import EcommerceAnalyzer
# df = io_utils.load_data()
check = EcommerceAnalyzer()
df = check.load_data()
check.top_3(df)
check.barKategori(df)
check.barStader(df)
check.mean(df)
check.intaktStad(df)
# Out:
#       category     revenue
# 1  Electronics  1364228.07
# 2       Sports   734653.42
# 3     Clothing   586744.91
# Medelvärde per order är:  1401.11 kr.
#         city     revenue
# 0  Stockholm  1227201.94
# 1   Göteborg   859019.65
# 2      Malmö   567926.32
# 3    Uppsala   551478.42
# 4   Västerås   297140.90

# %%
from src import metrics as mtr
from src import viz as Viz

mtr.income_by_category(df)
mtr.income_by_city(df)
Viz.line_sales_over_time(df)
# Out:
# Intäkt per kategori:
#       category     revenue
# 0       Beauty   163053.97
# 1     Clothing   586744.91
# 2  Electronics  1364228.07
# 3         Home   511070.87
# 4       Sports   734653.42
# 5         Toys   143015.99
# Tabellen visar intäkter per kategori.
# Den högsta intäkten är i kategorien Electronics 1364228.07 kr.
#
# Intäkt per stad:
#         city     revenue
# 0   Göteborg   859019.65
# 1      Malmö   567926.32
# 2  Stockholm  1227201.94
# 3    Uppsala   551478.42
# 4   Västerås   297140.90
# Tabellen visar intäkter per stad.
# Stockholm har den högsta intäkten 1227201.94 kr.
# Diagrammet visar hur intäkterna förändras från januari till june.
# Vi ser en ökning av försäljningen från mars till maj, medan intäkterna minskar från januari till mars och från maj till june.

# %%
from src.ecommerce import EcommerceAnalyzer
ea = EcommerceAnalyzer()
df = ea.load_data()

ea.total_revenue(df)
ea.total_units(df)
Viz.barintaktkategori(df)
# %pip install ipykernel pandas numpy matplotlib
# Out:
# Totala intäkter är: 3502767.23 kr.
# Totalt antal sålda enheter är: 7463 st.
# Intäkt per kategori:
#       category     revenue
# 0       Beauty   163053.97
# 1     Clothing   586744.91
# 2  Electronics  1364228.07
# 3         Home   511070.87
# 4       Sports   734653.42
# 5         Toys   143015.99
# Tabellen visar intäkter per kategori.
# Den högsta intäkten är i kategorien Electronics 1364228.07 kr.
# Diagrammet visar totala intäkter per kategori.

# %% [markdown]
# # Rekommendation

# %% [markdown]
# 1. Satsa på kategori ***Electronics*** i stad ***Stockholm*** under perioden ***March och May***.
# 2. Satsa på att öka den totala försäljningen under perioden ***January-March*** för att undvika nedgång, få en hållbar och konsekvent försäljning.
